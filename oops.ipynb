# %%
print("i am a strong")
# Out:
# i am a strong

# %%
class Dog:
    species="canine"

    def __init__(self,name,age):
        self.name=name
        self.age=age


dog1=Dog("buddy",24)

print(dog1.age)
# Out:
# 24

# %%
class Students:
    teacher="mohan" # class attribute

    def __init__(self,name,dept):
        self.name=name #instance attribute
        self.dept=dept

Student1=Students("Nithin","CSM")
Student2=Students("Sunny","CSE")

print(Student1.name,Student1.teacher)
print(Students.teacher)


Student1.name="deva"
print(Student1.name)

Students.teacher="kalyan"

print(Students.teacher)
# Out:
# Nithin mohan
# mohan
# deva
# kalyan

# %% [markdown]
# 3. Inheritance
# Inheritance allows a class (child class) to acquire properties and methods of another class (parent class). It supports hierarchical classification and promotes code reuse.
#
# Single Inheritance: A child class inherits from a single parent class.
#
# Multiple Inheritance: A child class inherits from more than one parent class.
#
# Multilevel Inheritance: A child class inherits from a parent class, which in turn inherits from another class.
#
# Hierarchical Inheritance: Multiple child classes inherit from a single parent class.
#
# Hybrid Inheritance: A combination of two or more types of inheritance.

# %%
class Animal:
    def sound(self):
        print("Animal make sound")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

d=Dog()

Dog().sound()
d.bark()
# Out:
# Animal make sound
# Dog barks

# %%
class vehicle:
    def start(self):
        print("vehicle started")

class car(vehicle):
    def drive(self):
        print("car is driving")

class electricalcar(car):
    def battery(self):
        print("battery powered")

e=electricalcar()
e.start()
e.drive()
# Out:
# vehicle started
# car is driving

# %%
class Father:
    def skills(self):
        print("Father: Driving")

class Mother:
    def skills(self):
        print("Mother: Cooking")

class Child(Father, Mother):
    pass

c = Child()
c.skills()   # Method Resolution Order (MRO)

print(Child.mro())
# Out:
# Father: Driving
# [<class '__main__.Child'>, <class '__main__.Father'>, <class '__main__.Mother'>, <class 'object'>]

# %% [markdown]
# Create a class Car with attributes brand, model, price.

# %%
class Car:
    def __init__(self,brand,model,price):
        self.brand=brand
        self.model=model
        self.price=price

    def innova(self):
        print(f"car brand is {self.brand}")

car1=Car("maruti","alto K10","3.7")
car1.innova()
# Out:
# car brand is maruti

# %%
class BankAccount:

    def __init__(self,name,balance):
        self.name=name
        self.balance=balance

    def deposit(self,amount):
        self.balance+=amount
        print("deposit successfull")
    def withdraw(self,amount):
        if self.balance < amount:
            print("insufficient")
        else:
            self.balance-=amount
            print("withdrawl successfull")
    def display_balance(self):
        print(f"balance is {self.balance}")

prs1=BankAccount("nithin",15000)
prs2=BankAccount("sunny",4500)


prs1.deposit(2000)
prs1.withdraw(500)
prs1.display_balance()
# Out:
# deposit successfull
# withdrwa successfull
# balance is 16500

# %%
class Laptop:

    def __init__(self,brand,ram,price):
        self.brand=brand
        self.ram=ram
        self.price=price

    def show_details(self):
        print(f"laptop name is {self.brand} and ram is {self.ram},price is {self.price}")


stu1=Laptop("lenova","8gb",45000)
stu1.show_details()
# Out:
# laptop name is lenova and ram is 8gb,price is 45000

# %%
class Student:
    def __init__(self,name,roll_no,marks):
        self.name=name
        self.roll_no=roll_no
        self.marks=marks

    def dispaly_details(self):
        print(f"student name is {self.name} and rollno is {self.roll_no} and his marks is {self.marks}")


Student1=Student("nithin",22781,56)
Student1.dispaly_details()
# Out:
# student name is nithin and rollno is 22781 and his marks is 56

# %%
class Mobile:

    def __init__(self,brand,model,price):
        self.brand=brand
        self.model=model
        self.price=price

    def discount(self,dis):
        dis=self.price*(dis/100)
        self.price-=dis
        print("applyed discount")

    def show_price(self):
        print(f"final price {self.price}")

mob1=Mobile("Moto","g67",10000)
mob1.discount(10)
mob1.show_price()
# Out:
# applyed discount
# final price 9000.0

# %%
class rectangle:
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        a=self.length*self.width
        print(a)

    def permiter(self):
        per=2*(self.length+self.width)
        print(per)

r1=rectangle(15,20)
r1.area()
r1.permiter()
# Out:
# 300
# 70

# %%
class Book:
    def __init__(self,title,author,price):
        self.title=title
        self.author=author
        self.price=price
        
    def apply_discount(self,percent):
        if self.price >= 500:
            percent+=self.price*(percent/100)
            self.price=self.price-percent
            print(f"price is {self.price}")
        else:
            print(f"self.price {self.price}")

    def display(self):
        print(f"book title is {self.title} and author is {self.author} and price is {self.price}")


bk1=Book("Paradise Lost","John Milton",600)
bk1.apply_discount(20)
bk1.display()
# Out:
# price is 460.0
# book title is Paradise Lost and author is John Milton and price is 460.0

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary

    def increase_salary(self,percent):
        increase=(self.salary*percent)/100
        self.salary+=increase
        print(f" increased salary {self.salary}")

    def display_salary(self):
        print(f" {self.name} salary is {self.salary}")

empl1=Employee("nithin",15000)
empl2=Employee("sunny",60000)

empl1.increase_salary(15)
empl1.display_salary()

empl2.increase_salary(15)
empl2.display_salary()
# Out:
#  increased salary 17250.0
#  nithin salary is 17250.0
#  increased salary 69000.0
#  sunny salary is 69000.0

# %% [markdown]
# Encapsulation

# %%
class Employee:
    def __init__(self, name,age):
        self.name = name
        self.age=age   # public attribute

    def display_name(self):   # public method
        print(self.name)

emp = Employee("John",56)
emp.display_name()   # Accessible
print(emp.name)
print(emp.age)      # Accessible
# Out:
# John
# John
# 56

# %% [markdown]
#  Protected members

# %%
class Employee:

    def __init__(self,name,age):
        self.name=name
        self._age=age

    
class SubEmployee(Employee):
        def show_age(self):
            print("age:",self._age)

emp=SubEmployee("ross",89)
print(emp.name)
emp.show_age()
# Out:
# age: 89
# ross
# age: 89

# %%
class Employee:
    def __init__(self, name, age):
        self.name = name       # public
        self._age = age        # protected

class SubEmployee(Employee):
    def show_age(self):
        print("Age:", self._age)   # Accessible in subclass

emp = SubEmployee("Ross", 30)
print(emp.name)        # Public accessible
emp.show_age()         # Protected accessed through subclass
# Out:
# Ross
# Age: 30

# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self._marks=marks

class substudent(Student):
    def show_marks(self):
        print(f"{self.name} is marks is : {self._marks}")

stu=substudent("nithin",85)
stu.show_marks()
# Out:
# nithin is marks is : 85

# %% [markdown]
# Private members

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.__salary=salary

    def show_salary(self):
        print("salary:",self.__salary)


emp=Employee("Nithin",60000)
print(emp.name)
emp.show_salary()
# Out:
# Nithin
# salary: 60000

# %% [markdown]
# Inheritance
#
# One class can reuse properties and methods of another class.
# Child class uses Parent class features.

# %%
class Person:
    def __init__(self,name):
        self.name=name

    def greet(self):
        print("hello")

class Student(Person):
    pass

s1=Student("nithin")
s1.greet()
# Out:
# hello

# %%
class Animal:
    def __init__(self,name):
        self.name=name

    def info(self):
        print("Animal name:", self.name)

class Dog(Animal):
    def Sound(self):
        print(self.name,"barks")

d=Dog("buddy")
d.info()
d.Sound()
# Out:
# Animal name: buddy
# buddy barks

# %%
class Animal:
    def __init__(self,name):
        self.name=name

    def info(self):
        print("Animal Name:",self.name)

class Dog(Animal):
    def sound(self):
        print("bowww")

d=Dog("buddy")
d.info()
d.sound()
# Out:
# Animal Name: buddy
# bowww

# %% [markdown]
# super() Function
# super() function is used to call the parent class’s methods. In particular, it is commonly used in the child class’s __init__() method to initialize inherited attributes. This way, the child class can leverage the functionality of the parent class.

# %%
class Animal:
    def __init__(self,name):
        self.name=name

    def info(self):
        print(self.name)

class Dog(Animal):
    def __init__(self, name,breed):
        super().__init__(name)
        self.breed=breed

    def detail(self):
        print(f"{self.name} is breed is {self.breed}")

d=Dog("buddy","golden Retriever")
d.info()
d.detail()
# Out:
# buddy
# buddy is breed is golden Retriever

# %% [markdown]
# Polymorphism

# %%
class Animal:
    def sound(self):
        print("animal makes sound")

class Dog(Animal):
    def sound(self):
        print("dog barks")

class Cat(Animal):

    def sound(self):
        print("cat meows")

a=Animal()
a.sound()
b=Dog()
b.sound()
# Out:
# animal makes sound
# dog barks

# %% [markdown]
# 🔷 1. Method Overriding (Runtime Polymorphism)
# ✅ Definition:
#
# Method Overriding happens when a child class provides its own implementation of a method that is already defined in the parent class.
#
# 👉 Same method name
# 👉 Same parameters
# 👉 Different implementation in child class
#
# 🌍 Real-Time Example:
#
# Think about a Vehicle.
#
# All vehicles have a method called start().
# But:
#
# Car → starts with key
#
# Bike → starts with self button
#
# Same method name, different behavior.

# %%
class Vehicle:
    def start(self):
        print("Vehicle is starting")

class Car(Vehicle):
    def start(self):   # Overriding
        print("Car starts with key")

class Bike(Vehicle):
    def start(self):   # Overriding
        print("Bike starts with self button")

v = Vehicle()
c = Car()
b = Bike()

v.start()
c.start()
b.start()
# Out:
# Vehicle is starting
# Car starts with key
# Bike starts with self button

# %% [markdown]
# 2. Method Overloading (Compile-time Polymorphism)
# ✅ Definition:
#
# Method Overloading means having multiple methods with the same name but different number of parameters.
#
# 👉 Same method name
# 👉 Different parameters
#
# ⚠ Important:
# Python does NOT support traditional method overloading like Java.
# But we can achieve it using default arguments.

# %% [markdown]
# Abstraction

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def start(self):
        pass

class Car(Vehicle):
    def start(self):
        print("car start")

c=Car()
c.start()
# Out:
# car start

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def start(self):
        pass

class Car(Vehicle):
    def start(self):
        print("started")

c=Car()
c.start()
# Out:
# started
